# %%
import matplotlib.pyplot as plt

# Data extracted from the provided text
steps = [0, 25, 50, 75, 100, 125, 150, 175, 200, 225, 250, 275, 300, 325, 350, 375, 400, 425, 450, 475, 500]
train_loss = [10.8313, 4.2611, 3.2897, 2.9436, 2.6551, 2.3732, 2.2236, 2.0688, 1.9210, 1.8090, 1.7133, 1.6047, 1.5223, 1.4350, 1.3688, 1.3019, 1.2615, 1.2158, 1.1840, 1.1436, 1.1173]
val_loss = [10.8507, 4.8989, 4.1890, 4.0981, 4.0062, 3.8422, 3.8175, 3.8437, 3.8292, 3.8051, 3.9185, 3.9087, 4.0040, 3.9541, 3.9872, 3.9836, 4.0889, 4.0302, 4.0603, 4.0832, 4.1024]

# %%
# Plotting the data
plt.figure(figsize=(12, 6))
plt.plot(steps, train_loss, label='Training Loss', marker='o')
plt.plot(steps, val_loss, label='Validation Loss', marker='x')
plt.xlabel('Steps')
plt.ylabel('Loss')
plt.title('Training and Validation Loss Over Steps')
plt.legend()
plt.grid(True)
plt.show()
